# %%
import pandas as pd
datos1=pd.read_excel('excel/excel1.xlsx')
df1=pd.DataFrame(datos1)

df1.drop(['Año','Mes','Region','Asignaciones especiales','Unidad monetaria','Clasificacion Sexo'],axis=1,inplace=True)
df1.drop(['Montos y horas extraordinarias diurnas','Montos y horas extraordinarias nocturnas'],axis=1,inplace=True)
df1.drop(['Montos y horas extraordinarias festivas','Fecha de inicio dd/mm/aa'],axis=1,inplace=True)
df1.drop(['Fecha de término dd/mm/aa','Viáticos'],axis=1,inplace=True)
df1.drop(['Unnamed: 0','Observaciones'],axis=1,inplace=True)
df1
# Out:
#          Estamento                          Nombre Completo Cargo o funcion  \
# 0        Directivo               AGUAYO LEAL, MONICA LORETO       DIRECTIVO
# 1        Directivo          AGUILLON MICHEL, DOMINGO ELISEO       DIRECTIVO
# 2         Auxiliar         ALEGRIA CASTILLO, DANILO ENRIQUE        AUXILIAR
# 3      Profesional              ALEGRIA PURRAN, JULIO CESAR     PROFESIONAL
# 4         Auxiliar        ALEGRIA PURRAN, MONICA DEL CARMEN        AUXILIAR
# 5         Auxiliar            AREVALO MENDEZ, NORA DEL CARM        AUXILIAR
# 6   Administrativo            CABEZAS MUÑOZ, LORENA SILVANA  ADMINISTRATIVO
# 7      Profesional          CAMPOS QUEZADA, MARTA ROSE MERY     PROFESIONAL
# 8        Directivo           CASTRO VASQUEZ, MARICEL ANDREA       DIRECTIVO
# 9          Técnico            CERDA ROZAS, EDISON ALEXANDRO         TECNICO
# 10       Directivo              GARCIA GARCIA, RAMON ORESTE       DIRECTIVO
# ...

# %%
datos2=pd.read_excel('excel/excel2.xlsx')
df2=pd.DataFrame(datos2)
df2.drop(['Año','Mes','Region','Asignaciones especiales','Unidad monetaria','Clasificacion Sexo'],axis=1,inplace=True)
df2.drop(['Montos y horas extraordinarias diurnas','Montos y horas extraordinarias nocturnas'],axis=1,inplace=True)
df2.drop(['Montos y horas extraordinarias festivas','Fecha de inicio dd/mm/aa'],axis=1,inplace=True)
df2.drop(['Fecha de término dd/mm/aa','Viáticos'],axis=1,inplace=True)
df2.drop(['Unnamed: 0','Observaciones'],axis=1,inplace=True)
df2
# Out:
#          Estamento                          Nombre Completo  \
# 0   Administrativo           AGUILAR VASQUEZ, ROSA ETELVINA
# 1          Técnico               BALDI ARANEDA, ANDRES IVAN
# 2   Administrativo              BELLO MEDINA, JOSE ROBINSON
# 3   Administrativo         BELTRAN ALVIAL, HERIBERTO JAVIER
# 4   Administrativo          CAMPOS SANHUEZA, HUGO ALEJANDRO
# 5   Administrativo               CARRILLO RIQUELME, MARIBEL
# 6   Administrativo             CARRILLO ROA, DAISY VIRGINIA
# 7   Administrativo  CHICAGUALA HUENCHUMAN, JHONATAN BASILIO
# 8   Administrativo          CONTRERAS CARRILLO, BLANCA ROSA
# 9          Técnico         CORTES CARRILLO, MARIA MAGDALENA
# 10  Administrativo             DURAN BURALEO, ORIETTA BELEN
# 11  Administrativo            FLORES AVELLO, CARLOS ALBERTO
# 12  Administrativo       FRITZ IGLESIAS, MARIELA DEL CARMEN
# 13  Administrativo                  GATICA SEPULVEDA, DAYSI
# 14  Administrativo              GOMEZ SALGADO, LUIS GONZALO
# ...

# %%
datos3=pd.read_excel('excel/excel3.xlsx')
df3=pd.DataFrame(datos3)
df3.drop(['Año','Mes','Region','Asignaciones especiales','Unidad monetaria','Clasificacion Sexo'],axis=1,inplace=True)
df3.drop(['Montos y horas extraordinarias diurnas','Montos y horas extraordinarias nocturnas'],axis=1,inplace=True)
df3.drop(['Montos y horas extraordinarias festivas','Fecha de inicio dd/mm/aa'],axis=1,inplace=True)
df3.drop(['Fecha de término dd/mm/aa','Viáticos'],axis=1,inplace=True)
df3.drop(['Unnamed: 0','Observaciones'],axis=1,inplace=True)
df3
# Out:
#                                             Estamento  \
# 0                                            Jefatura
# 1                                            Jefatura
# 2                                           Directivo
# 3                                         Profesional
# 4                                         Profesional
# 5                                           Directivo
# 6                                             Técnico
# 7                                            Jefatura
# 8                                            Auxiliar
# 9                                           Directivo
# 10                                          Directivo
# 11                                           Auxiliar
# 12                                     Administrativo
# 13                                     Administrativo
# 14                                            Técnico
# 15                                          Directivo
# ...

# %%
datos4=pd.read_excel('excel/excel4.xlsx')
df4=pd.DataFrame(datos4)
df4.drop(['Año','Mes','Region','Asignaciones especiales','Unidad monetaria','Clasificacion Sexo'],axis=1,inplace=True)
df4.drop(['Montos y horas extraordinarias diurnas','Montos y horas extraordinarias nocturnas'],axis=1,inplace=True)
df4.drop(['Montos y horas extraordinarias festivas','Fecha de inicio dd/mm/aa'],axis=1,inplace=True)
df4.drop(['Fecha de término dd/mm/aa','Viáticos'],axis=1,inplace=True)
df4.drop(['Unnamed: 0','Observaciones'],axis=1,inplace=True)
df4
# Out:
#          Estamento                       Nombre Completo  \
# 0         Auxiliar             ALTAMIRANO MORALES, YANET
# 1        Directivo           ARIAS CONTRERAS, JORGE LUIS
# 2         Jefatura        ARRIAGADA ZAPATA, NURTY LILIAN
# 3        Directivo       BELTRAN BRAVO, TATIANA CAROLINA
# 4         Jefatura            BURGOS AEDO, JORGE ENRIQUE
# 5        Directivo     CASTILLO ACUÑA, VALESKA ELIZABETH
# 6         Auxiliar                    DIAZ MUÑOZ, LESSLY
# 7        Directivo         ENCINA FONSECA, DAVID EDUARDO
# 8   Administrativo                  FICA CRISOSTO, JORGE
# 9   Administrativo             FUENTES GONZALEZ, ADRIANA
# 10        Auxiliar             INOSTROZA MONTES, JESSICA
# 11       Directivo      MELLADO VALLADARES, JOSE ALBERTO
# 12         Alcalde        MELO MARQUEZ, FRANCISCO JAVIER
# 13       Directivo         MUÑOZ OVIEDO, NATTALY VALESKA
# 14  Administrativo                OÑATE GONZALEZ, GLORIA
# ...

# %%
datos5=pd.read_excel('excel/excel5.xlsx')
df5=pd.DataFrame(datos5)
df5.drop(['Año','Mes','Region','Asignaciones especiales','Unidad monetaria','Clasificacion Sexo'],axis=1,inplace=True)
df5.drop(['Montos y horas extraordinarias diurnas','Montos y horas extraordinarias nocturnas'],axis=1,inplace=True)
df5.drop(['Montos y horas extraordinarias festivas','Fecha de inicio dd/mm/aa'],axis=1,inplace=True)
df5.drop(['Fecha de término dd/mm/aa','Viáticos'],axis=1,inplace=True)
df5.drop(['Unnamed: 0','Observaciones'],axis=1,inplace=True)
df5
# Out:
#           Estamento                            Nombre Completo  \
# 0          Auxiliar              Acuña Molina, Eduardo Froilán
# 1            Chofer                  Agurto Daza, Luis Alberto
# 2            Chofer               Agurto Daza, Ricardo Antonio
# 3    Administrativo                Agurto Vargas, Orietta Mary
# 4    Administrativo            Alarcón Alarcón, Soledad Susana
# 5            Chofer          Alarcón Contreras, Nelson Orlando
# 6    Administrativo   Alarcón Fuentes, Marisol Teresa De Jesús
# 7           Técnico           Alarcón Fuentes, Patricia Ivonne
# 8         Directivo            Alarcón Fuentes, Rodrigo Andrés
# 9       Profesional               Alarcón Muñoz, Pedro Gonzalo
# 10         Auxiliar             Alarcón Santos, Carlos Arnoldo
# 11           Chofer           Altamirano Tiznado, José Abraham
# 12         Auxiliar              Amigo Ramírez, Herminda Elena
# 13      Profesional           Arancibia Barra, Cristian Fabián
# ...

# %%
datos6=pd.read_excel('excel/excel6.xlsx')
df6=pd.DataFrame(datos6)
df6.drop(['Año','Mes','Region','Asignaciones especiales','Unidad monetaria','Clasificacion Sexo'],axis=1,inplace=True)
df6.drop(['Montos y horas extraordinarias diurnas','Montos y horas extraordinarias nocturnas'],axis=1,inplace=True)
df6.drop(['Montos y horas extraordinarias festivas','Fecha de inicio dd/mm/aa'],axis=1,inplace=True)
df6.drop(['Fecha de término dd/mm/aa','Viáticos'],axis=1,inplace=True)
df6.drop(['Unnamed: 0','Observaciones'],axis=1,inplace=True)
df6
# Out:
#          Estamento                           Nombre Completo  \
# 0   Administrativo                Abello Oñate, Rosa Viviana
# 1          Técnico            Acuña Jara, Yolanda Del Carmen
# 2         Auxiliar        Barriga Navarrete, Gabriel Antonio
# 3      Profesional              Burgos Burgos, Yohana Andrea
# 4          Técnico           Cardenas Veloso, Rodrigo Alexis
# 5   Administrativo      Carrasco Mieres, Jimena Del Transito
# 6   Administrativo                Castro Rojas, Nancy Eliana
# 7   Administrativo         Contreras Carrillo, Victor Andres
# 8   Administrativo              Cordova Cuevas, Pablo Emilio
# 9        Directivo              Cuevas Reyes, Marcia Clarina
# 10  Administrativo       De La Cruz Sandoval, Pamela Beatriz
# 11       Directivo           Dueñas Aguayo, Francisco Javier
# 12        Auxiliar           Figueroa Vilches, Soledad Paola
# 13        Auxiliar             Friz De La Peña, Omar Alfredo
# ...

# %%
dftotal= pd.concat([df1, df2,df3,df4,df5,df6], axis=0)
dftotal
# Out:
#          Estamento                          Nombre Completo  \
# 0        Directivo               AGUAYO LEAL, MONICA LORETO
# 1        Directivo          AGUILLON MICHEL, DOMINGO ELISEO
# 2         Auxiliar         ALEGRIA CASTILLO, DANILO ENRIQUE
# 3      Profesional              ALEGRIA PURRAN, JULIO CESAR
# 4         Auxiliar        ALEGRIA PURRAN, MONICA DEL CARMEN
# 5         Auxiliar            AREVALO MENDEZ, NORA DEL CARM
# 6   Administrativo            CABEZAS MUÑOZ, LORENA SILVANA
# 7      Profesional          CAMPOS QUEZADA, MARTA ROSE MERY
# 8        Directivo           CASTRO VASQUEZ, MARICEL ANDREA
# 9          Técnico            CERDA ROZAS, EDISON ALEXANDRO
# 10       Directivo              GARCIA GARCIA, RAMON ORESTE
# 11     Profesional            HERRERA NEIRA, FELIPE EDUARDO
# 12        Jefatura           LEON REBOLLEDO, EDITH ANGELICA
# 13  Administrativo  MALDONADO MEDINA, ADRIANA DE LAS NIEVES
# 14     Profesional            MEDINA CASTRO, MARIA CRISTINA
# ...

# %%
dftotal['Estamento'].value_counts(dropna=False)
# Out:
# Administrativo                                                                              180
# Auxiliar                                                                                     97
# Profesional                                                                                  71
# Técnico                                                                                      67
# Directivo                                                                                    64
# Chofer                                                                                       33
# Jefatura                                                                                     24
# Alcalde                                                                                       4
# Sin Estamento                                                                                 2
# Médicos cirujanos, farmacéuticos, químico-farmacéuticos, bioquímicos, cirujano-dentistas      1
# ...

# %%
p=[]
p.append(dftotal[dftotal['Estamento']=='Administrativo']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Auxiliar']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Profesional']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Técnico']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Directivo']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Chofer']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Jefatura']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Alcalde']['Estamento'].count())
p.append(dftotal[dftotal['Estamento']=='Sin Estamento']['Estamento'].count())
p
# Out:
# [180, 97, 71, 67, 64, 33, 24, 4, 2]

# %%
dftotal['Grado'].value_counts(dropna=False)
# Out:
# 13     97
# 14     52
# 18     52
# 12     40
# 10     39
# 15     32
# 6      27
# 11     27
# 16     26
# 8      24
# 9      24
# 7      20
# 17     14
# 4      11
# 12°     8
# 6°      7
# 13°     5
# 14°     5
# 15°     5
# 11°     4
# 10°     4
# 21      3
# 16°     3
# 5       3
# 19      2
# 9°      2
# 8°      2
# 4°      1
# 99      1
# 7°      1
# 13º     1
# 2       1
# Name: Grado, dtype: int64

# %%
d=[]
d.append(dftotal[dftotal['Grado']==13]['Grado'].count()+dftotal[dftotal['Grado']=='13°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==18]['Grado'].count()+dftotal[dftotal['Grado']=='18°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==14]['Grado'].count()+dftotal[dftotal['Grado']=='14°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==12]['Grado'].count()+dftotal[dftotal['Grado']=='12°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==10]['Grado'].count()+dftotal[dftotal['Grado']=='10°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==15]['Grado'].count()+dftotal[dftotal['Grado']=='15°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==6]['Grado'].count()+dftotal[dftotal['Grado']=='6°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==11]['Grado'].count()+dftotal[dftotal['Grado']=='11°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==16]['Grado'].count()+dftotal[dftotal['Grado']=='16°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==8]['Grado'].count()+dftotal[dftotal['Grado']=='8°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==9]['Grado'].count()+dftotal[dftotal['Grado']=='9°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==7]['Grado'].count()+dftotal[dftotal['Grado']=='7°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==17]['Grado'].count()+dftotal[dftotal['Grado']=='17°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==4]['Grado'].count()+dftotal[dftotal['Grado']=='4°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==21]['Grado'].count()+dftotal[dftotal['Grado']=='21°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==5]['Grado'].count()+dftotal[dftotal['Grado']=='5°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==19]['Grado'].count()+dftotal[dftotal['Grado']=='19°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==99]['Grado'].count()+dftotal[dftotal['Grado']=='99°']['Grado'].count())
d.append(dftotal[dftotal['Grado']==2]['Grado'].count()+dftotal[dftotal['Grado']=='2°']['Grado'].count())

d
# Out:
# [102, 52, 57, 48, 43, 37, 34, 31, 29, 26, 26, 21, 14, 12, 3, 3, 2, 1, 1]

# %%
from flask import Flask, render_template
app= Flask(__name__)
@app.route('/Mun1')
def Mun1():
      return render_template("index.html", data=df1.to_html(), name="Municipalidad de Alto Bio Bio")
@app.route('/Mun2')
def Mun2():
      return render_template("index.html", data=df2.to_html(), name="Municipalidad de Arauco")
@app.route('/Mun3')
def Mun3():
      return render_template("index.html", data=df3.to_html(), name="Municipalidad de Nacimiento")
@app.route('/Mun4')
def Mun4():
      return render_template("index.html", data=df4.to_html(), name="Municipalidad de Negrete")
@app.route('/Mun5')
def Mun5():
      return render_template("index.html", data=df5.to_html(), name="Municipalidad de Talcahuano")
@app.route('/Mun6')
def Mun6():
      return render_template("index.html", data=df6.to_html(), name="Municipalidad de Tucapel")
@app.route('/Main')
def Main():
      return render_template("main.html", lista=p, lista2=d)
@app.route('/Info')
def Acerca():
      return render_template("acerca.html")
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
